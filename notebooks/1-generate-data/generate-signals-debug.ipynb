# %% [markdown]
# - About the parameters
# Two parameters for the location on the sky: Alpha, Delta
# Three parameters for the orientation of the source: cosi, psi, phi
# One parameter that describes the "strength" of the signal: h0
# Two intrinsic parameters: frequency and spin-down: F0, F1
#
# -  FFTs
# Hi.Is there a fixed window length for fourier transform？
#
# For this kind of signal the recommended lenght is 1800seconds (30 mins). There might be gaps in the timestamp but the considered length is 1800 seconds. Rodrigo can confirm better. :)
#
# Yes, each timestamp labels a period of time of 1800s (you can check that by noting the frequency resolution of 1/1800 Hz), but timestamps need not to be consecutive (i.e. there may be times at which no data is collected).
#
# - About targets
#
# Hey Rodrigo Tenorio, thank you for providing resources for generating more data. I am unclear about the "target" part while generating the data. The kenrel provided to generate the data does not seem to the information about the label (target 1, 0, or -1). Or am I missing something? Thanks in advance.
#
# 0/1 labels refer to whether we included a simulated signal to that sample (1) or if it consists only on noise.
# In terms of the quantities of the kernel your refer to, a label of 1 would correspond to a signal with an amplitude h0 greater than 0 (i. e. there's a signal), while a label of 0 would correspond to not having a signal (i.e. amplitude h0 = 0).
# The same definition can be made in terms of SNR: Label of 1 corresponds to SNR > 0, label 0 corresponds to SNR = 0 (no signal added at all).

# %%
import os
import sys

import numpy as np
import matplotlib.pyplot as plt

import pyfstat

from scipy import stats
from tqdm import tqdm
# Out:
# 22-11-05 09:40:46.721 pyfstat INFO    : Running PyFstat version 1.18.1+1.73ad1acd.clean
# 22-11-05 09:40:47.091 pyfstat.utils.importing INFO    : No $DISPLAY environment variable found, so importing matplotlib.pyplot with non-interactive 'Agg' backend.

# %%
def combine_amplitudes(amplitude_0, amplitude_1):
    # Get the real part of the amplitudes
    real_0 = amplitude_0.real
    real_1 = amplitude_1.real
    # Get the imaginary part of the amplitudes
    imag_0 = amplitude_0.imag
    imag_1 = amplitude_1.imag
    # normalize the amplitudes to be between 0 and 1
    real_0 = (real_0 - real_0.min()) / (real_0.max() - real_0.min())
    real_1 = (real_1 - real_1.min()) / (real_1.max() - real_1.min())
    imag_0 = (imag_0 - imag_0.min()) / (imag_0.max() - imag_0.min())
    imag_1 = (imag_1 - imag_1.min()) / (imag_1.max() - imag_1.min())
    # Expand the dims of the real and imaginary parts
    real_0 = np.expand_dims(real_0, axis=0)
    real_1 = np.expand_dims(real_1, axis=0)
    imag_0 = np.expand_dims(imag_0, axis=0)
    imag_1 = np.expand_dims(imag_1, axis=0)
    # Make a vstack of the amplitudes
    amplitudes = np.vstack((real_0, imag_0, real_1, imag_1))
    return amplitudes

# %%
def _generate_signals(num_signals, tfrac, prior_index, duration, draw_signal, sqrtSX):
    tmin = 1238166018
    dt = 10558244
    
    # These parameters describe background noise and data format
    writer_kwargs = {
                    "tstart": int(tmin + dt*tfrac), # 1238177971, # 1238166018,
                    "duration": 1800 * duration,
                    "detectors": "H1,L1",        
                    "sqrtSX": sqrtSX, # lambda: 10**stats.uniform(-26, -23).rvs(),          
                    "Tsft": 1800,             
                    "SFTWindowType": "tukey", 
                    "SFTWindowBeta": 0.01,
                    }

    # This class allows us to sample signal parameters from a specific population.
    # Implicitly, sky positions are drawn uniformly across the celestial sphere.
    # PyFstat also implements a convenient set of priors to sample a population
    # of isotropically oriented neutron stars.
    signal_parameters_generator = pyfstat.AllSkyInjectionParametersGenerator(
        priors={
            "tref": writer_kwargs["tstart"],
            "F0": {"uniform": {"low": 50.0, "high": 500.}},
            "Band": 359/1800 ,
            "F1": lambda: 10**stats.uniform(-12, 4).rvs(),
            "F2": 0,
            "h0": lambda: writer_kwargs["sqrtSX"] / stats.uniform(1, 10).rvs() if draw_signal else 0,
            **pyfstat.injection_parameters.isotropic_amplitude_priors,
        },
    )

    snrs = np.zeros(num_signals)

    for ind in range(num_signals):

        # Draw signal parameters.
        # Noise can be drawn by setting `params["h0"] = 0
        params = signal_parameters_generator.draw()
        
        DIRECTORY_TMP = f"~/Documents/TMP_NOT-SO-PURE_signals_true_{ind}_{prior_index}" if draw_signal else f"/TMP_5-generate-signals/signals_false_{ind}_{prior_index}"
        
        writer_kwargs["outdir"] = DIRECTORY_TMP
        
        writer = pyfstat.Writer(**writer_kwargs, **params)
        writer.make_data()
        
        paths = writer.sftfilepath.split(";")
        
        # Data can be read as a numpy array using PyFstat
        frequency, timestamps, amplitudes_0 = pyfstat.utils.get_sft_as_arrays(paths[0])
        frequency, timestamps, amplitudes_1 = pyfstat.utils.get_sft_as_arrays(paths[1])
        x = combine_amplitudes(amplitudes_0["H1"], amplitudes_1["L1"])
        
        return x

def generate_signals(num_signals=10, tfrac=0.9, prior_index=0,duration=4586, draw_signal=True, sqrtSX=1.E-23):

                     # Generate signals with parameters drawn from a specific population

    try: # 1238166018, 1248724262)
        _generate_signals(num_signals, tfrac, prior_index, duration, draw_signal, sqrtSX)
            
                
    except:
        print("LOL it failed")
        # Return raise error

# %%
x = _generate_signals(num_signals=1, tfrac=0.1, prior_index=0,duration=500, draw_signal=True, sqrtSX=1.E-23)
# Out:
# 22-11-05 09:44:59.471 pyfstat.core INFO    : Creating Writer object...
# 22-11-05 09:44:59.472 pyfstat.utils.ephemeris INFO    : No /home/viktor/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-11-05 09:44:59.477 pyfstat.make_sfts INFO    : Generating SFTs with fmin=83.27062122306017, Band=0.19944444444444445
# 22-11-05 09:44:59.478 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-11-05 09:44:59.478 pyfstat.make_sfts INFO    : ...OK: config file ~/Documents/TMP_NOT-SO-PURE_signals_true_0_0/PyFstat.cff already exists.
# 22-11-05 09:44:59.479 pyfstat.make_sfts INFO    : ...file contents unmatched, updating ~/Documents/TMP_NOT-SO-PURE_signals_true_0_0/PyFstat.cff.
# 22-11-05 09:44:59.479 pyfstat.make_sfts INFO    : Writing config file: ~/Documents/TMP_NOT-SO-PURE_signals_true_0_0/PyFstat.cff
# 22-11-05 09:44:59.479 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-11-05 09:44:59.480 pyfstat.make_sfts INFO    : ...no SFT file matching '~/Documents/TMP_NOT-SO-PURE_signals_true_0_0/H-500_H1_1800SFT_PyFstat-1239221842-900000.sft' found. Will create new SFT file(s).
# 22-11-05 09:44:59.480 pyfstat.utils.cli INFO    : Now executing: lalpulsar_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="~/Documents/TMP_NOT-SO-PURE_signals_true_0_0" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="1e-23" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1239221842 --duration=900000 --fmin=83.27062122306017 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="~/Documents/TMP_NOT-SO-PURE_signals_true_0_0/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-11-05 09:45:00.202 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: ~/Documents/TMP_NOT-SO-PURE_signals_true_0_0/H-500_H1_1800SFT_PyFstat-1239221842-900000.sft;~/Documents/TMP_NOT-SO-PURE_signals_true_0_0/L-500_L1_1800SFT_PyFstat-1239221842-900000.sft
# 22-11-05 09:45:00.202 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-11-05 09:45:00.235 pyfstat.utils.sft INFO    : Loading 500 SFTs from H1...
# 22-11-05 09:45:01.397 pyfstat.utils.sft INFO    : Loading 500 SFTs from L1...

# %%
x.shape
# Out:
# (4, 360, 500)

# %%
num_signals = 50
num_priors = 500

sqrtX = np.logspace(-23.5, -22.5, num=num_priors)
tfrac = np.linspace(0, 1, num=num_priors)

# %%
from joblib import Parallel, delayed

# generate_dataset(train_files, indx, train_test_label="train")
Parallel(n_jobs=6)(delayed(generate_signals)(num_signals=num_signals,tfrac=tf, prior_index=prior_index, duration=360, draw_signal=True, sqrtSX=sqrtX[prior_index])  for prior_index, tf in zip(range(num_priors), tfrac))
# Out:
# 22-10-28 13:53:59.079 pyfstat INFO    : Running PyFstat version 1.18.1+1.73ad1acd.clean
# 22-10-28 13:53:59.084 pyfstat INFO    : Running PyFstat version 1.18.1+1.73ad1acd.clean
# 22-10-28 13:53:59.093 pyfstat INFO    : Running PyFstat version 1.18.1+1.73ad1acd.clean
# 22-10-28 13:53:59.107 pyfstat INFO    : Running PyFstat version 1.18.1+1.73ad1acd.clean
# 22-10-28 13:53:59.114 pyfstat INFO    : Running PyFstat version 1.18.1+1.73ad1acd.clean
# 22-10-28 13:53:59.125 pyfstat INFO    : Running PyFstat version 1.18.1+1.73ad1acd.clean
# 22-10-28 13:53:59.208 pyfstat.utils.importing INFO    : No $DISPLAY environment variable found, so importing matplotlib.pyplot with non-interactive 'Agg' backend.
# 22-10-28 13:53:59.209 pyfstat.utils.importing INFO    : No $DISPLAY environment variable found, so importing matplotlib.pyplot with non-interactive 'Agg' backend.
# 22-10-28 13:53:59.222 pyfstat.utils.importing INFO    : No $DISPLAY environment variable found, so importing matplotlib.pyplot with non-interactive 'Agg' backend.
# 22-10-28 13:53:59.238 pyfstat.utils.importing INFO    : No $DISPLAY environment variable found, so importing matplotlib.pyplot with non-interactive 'Agg' backend.
# 22-10-28 13:53:59.238 pyfstat.utils.importing INFO    : No $DISPLAY environment variable found, so importing matplotlib.pyplot with non-interactive 'Agg' backend.
# 22-10-28 13:53:59.249 pyfstat.utils.importing INFO    : No $DISPLAY environment variable found, so importing matplotlib.pyplot with non-interactive 'Agg' backend.
# 22-10-28 13:54:00.074 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:00.074 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:00.080 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:00.080 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:00.089 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:00.089 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:00.095 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:00.095 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : Generating SFTs with fmin=498.1101061718547, Band=0.19944444444444445
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : Generating SFTs with fmin=341.1222468468092, Band=0.19944444444444445
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : Generating SFTs with fmin=433.05787177387, Band=0.19944444444444445
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : Generating SFTs with fmin=460.8043959725106, Band=0.19944444444444445
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_2/PyFstat.cff found.
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_4/PyFstat.cff found.
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_1/PyFstat.cff found.
# 22-10-28 13:54:00.108 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_0/PyFstat.cff found.
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_1/PyFstat.cff
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_2/PyFstat.cff
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_0/PyFstat.cff
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_4/PyFstat.cff
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_0/H-360_H1_1800SFT_PyFstat-1238166018-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_2/H-360_H1_1800SFT_PyFstat-1238208335-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_4/H-360_H1_1800SFT_PyFstat-1238250653-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:00.109 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_0" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.1622776601683795e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238166018 --duration=648000 --fmin=460.8043959725106 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_0/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:00.109 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_1/H-360_H1_1800SFT_PyFstat-1238187176-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:00.109 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_2" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.1915967637605545e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238208335 --duration=648000 --fmin=341.1222468468092 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_2/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:00.109 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_1" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.1769033895140374e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238187176 --duration=648000 --fmin=433.05787177387 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_1/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:00.109 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_4" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.2211876998506396e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238250653 --duration=648000 --fmin=498.1101061718547 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_4/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:00.113 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:00.114 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:00.114 pyfstat.make_sfts INFO    : Generating SFTs with fmin=357.9466015081831, Band=0.19944444444444445
# 22-10-28 13:54:00.114 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:00.114 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_5/PyFstat.cff found.
# 22-10-28 13:54:00.114 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_5/PyFstat.cff
# 22-10-28 13:54:00.114 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:00.114 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_5/H-360_H1_1800SFT_PyFstat-1238271812-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:00.115 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_5" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.2360858917655993e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238271812 --duration=648000 --fmin=357.9466015081831 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_5/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:00.116 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:00.117 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:00.117 pyfstat.make_sfts INFO    : Generating SFTs with fmin=314.2838767763814, Band=0.19944444444444445
# 22-10-28 13:54:00.117 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:00.117 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_3/PyFstat.cff found.
# 22-10-28 13:54:00.117 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_3/PyFstat.cff
# 22-10-28 13:54:00.118 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:00.118 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_3/H-360_H1_1800SFT_PyFstat-1238229494-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:00.118 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_3" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.2063580957698235e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238229494 --duration=648000 --fmin=314.2838767763814 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_3/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:02.323 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_4/H-360_H1_1800SFT_PyFstat-1238250653-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_4/L-360_L1_1800SFT_PyFstat-1238250653-648000.sft
# 22-10-28 13:54:02.323 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:02.327 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_5/H-360_H1_1800SFT_PyFstat-1238271812-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_5/L-360_L1_1800SFT_PyFstat-1238271812-648000.sft
# 22-10-28 13:54:02.327 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:02.327 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_0/H-360_H1_1800SFT_PyFstat-1238166018-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_0/L-360_L1_1800SFT_PyFstat-1238166018-648000.sft
# 22-10-28 13:54:02.327 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:02.363 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:02.367 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:02.373 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:02.442 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:02.442 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:02.454 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:02.527 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:02.528 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:02.529 pyfstat.make_sfts INFO    : Generating SFTs with fmin=492.3815302558541, Band=0.19944444444444445
# 22-10-28 13:54:02.529 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:02.529 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_5/PyFstat.cff found.
# 22-10-28 13:54:02.529 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_5/PyFstat.cff
# 22-10-28 13:54:02.530 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:02.530 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_5/H-360_H1_1800SFT_PyFstat-1238271812-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:02.530 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_5" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.2360858917655993e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238271812 --duration=648000 --fmin=492.3815302558541 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_5/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:02.531 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:02.531 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:02.531 pyfstat.make_sfts INFO    : Generating SFTs with fmin=396.95069463386193, Band=0.19944444444444445
# 22-10-28 13:54:02.532 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:02.532 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_4/PyFstat.cff found.
# 22-10-28 13:54:02.532 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_4/PyFstat.cff
# 22-10-28 13:54:02.532 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:02.532 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_4/H-360_H1_1800SFT_PyFstat-1238250653-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:02.532 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_4" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.2211876998506396e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238250653 --duration=648000 --fmin=396.9506946338619 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_4/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:02.537 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:02.538 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:02.538 pyfstat.make_sfts INFO    : Generating SFTs with fmin=320.96138697545484, Band=0.19944444444444445
# 22-10-28 13:54:02.539 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:02.539 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_0/PyFstat.cff found.
# 22-10-28 13:54:02.539 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_0/PyFstat.cff
# 22-10-28 13:54:02.539 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:02.539 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_0/H-360_H1_1800SFT_PyFstat-1238166018-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:02.539 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_0" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.1622776601683795e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238166018 --duration=648000 --fmin=320.9613869754548 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_0/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:02.765 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_3/H-360_H1_1800SFT_PyFstat-1238229494-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_3/L-360_L1_1800SFT_PyFstat-1238229494-648000.sft
# 22-10-28 13:54:02.766 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:02.801 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:02.823 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:02.854 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_2/H-360_H1_1800SFT_PyFstat-1238208335-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_2/L-360_L1_1800SFT_PyFstat-1238208335-648000.sft
# 22-10-28 13:54:02.854 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:02.876 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:02.877 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:02.877 pyfstat.make_sfts INFO    : Generating SFTs with fmin=323.6108824627412, Band=0.19944444444444445
# 22-10-28 13:54:02.877 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:02.877 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_3/PyFstat.cff found.
# 22-10-28 13:54:02.878 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_3/PyFstat.cff
# 22-10-28 13:54:02.878 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:02.878 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_3/H-360_H1_1800SFT_PyFstat-1238229494-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:02.878 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_3" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.2063580957698235e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238229494 --duration=648000 --fmin=323.6108824627412 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_3/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:02.881 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:02.898 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_1/H-360_H1_1800SFT_PyFstat-1238187176-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_1/L-360_L1_1800SFT_PyFstat-1238187176-648000.sft
# 22-10-28 13:54:02.899 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:02.901 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:02.921 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:02.936 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:02.957 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:02.957 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:02.958 pyfstat.make_sfts INFO    : Generating SFTs with fmin=277.90425538380686, Band=0.19944444444444445
# 22-10-28 13:54:02.958 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:02.958 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_2/PyFstat.cff found.
# 22-10-28 13:54:02.958 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_2/PyFstat.cff
# 22-10-28 13:54:02.959 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:02.959 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_2/H-360_H1_1800SFT_PyFstat-1238208335-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:02.959 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_2" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.1915967637605545e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238208335 --duration=648000 --fmin=277.9042553838069 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_2/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:02.976 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:02.977 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:02.977 pyfstat.make_sfts INFO    : Generating SFTs with fmin=339.0536655841947, Band=0.19944444444444445
# 22-10-28 13:54:02.977 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:02.977 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_1/PyFstat.cff found.
# 22-10-28 13:54:02.978 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_1/PyFstat.cff
# 22-10-28 13:54:02.978 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:02.978 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_1/H-360_H1_1800SFT_PyFstat-1238187176-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:02.978 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_1" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.1769033895140374e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238187176 --duration=648000 --fmin=339.0536655841947 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_1/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:04.077 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_5/H-360_H1_1800SFT_PyFstat-1238271812-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_5/L-360_L1_1800SFT_PyFstat-1238271812-648000.sft
# 22-10-28 13:54:04.077 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:04.102 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:04.115 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:04.152 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:04.152 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:04.153 pyfstat.make_sfts INFO    : Generating SFTs with fmin=145.08836469697906, Band=0.19944444444444445
# 22-10-28 13:54:04.153 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:04.153 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_5/PyFstat.cff found.
# 22-10-28 13:54:04.153 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_5/PyFstat.cff
# 22-10-28 13:54:04.154 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:04.154 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_5/H-360_H1_1800SFT_PyFstat-1238271812-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:04.154 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_5" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.2360858917655993e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238271812 --duration=648000 --fmin=145.0883646969791 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_5/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:04.227 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_3/H-360_H1_1800SFT_PyFstat-1238229494-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_3/L-360_L1_1800SFT_PyFstat-1238229494-648000.sft
# 22-10-28 13:54:04.228 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:04.255 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_2/H-360_H1_1800SFT_PyFstat-1238208335-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_2/L-360_L1_1800SFT_PyFstat-1238208335-648000.sft
# 22-10-28 13:54:04.256 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:04.258 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:04.276 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:04.278 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:04.291 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:04.325 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:04.325 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:04.326 pyfstat.make_sfts INFO    : Generating SFTs with fmin=317.55055398640724, Band=0.19944444444444445
# 22-10-28 13:54:04.326 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:04.326 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_2/PyFstat.cff found.
# 22-10-28 13:54:04.326 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_2/PyFstat.cff
# 22-10-28 13:54:04.327 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:04.327 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_2/H-360_H1_1800SFT_PyFstat-1238208335-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:04.327 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:04.327 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_2" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.1915967637605545e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238208335 --duration=648000 --fmin=317.5505539864072 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_2/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:04.327 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:04.328 pyfstat.make_sfts INFO    : Generating SFTs with fmin=164.22869218465976, Band=0.19944444444444445
# 22-10-28 13:54:04.328 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:04.328 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_3/PyFstat.cff found.
# 22-10-28 13:54:04.328 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_3/PyFstat.cff
# 22-10-28 13:54:04.328 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:04.329 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_3/H-360_H1_1800SFT_PyFstat-1238229494-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:04.329 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_3" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.2063580957698235e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238229494 --duration=648000 --fmin=164.2286921846598 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_3/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:04.659 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_0/H-360_H1_1800SFT_PyFstat-1238166018-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_0/L-360_L1_1800SFT_PyFstat-1238166018-648000.sft
# 22-10-28 13:54:04.660 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:04.689 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:04.708 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:04.763 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:04.764 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:04.764 pyfstat.make_sfts INFO    : Generating SFTs with fmin=497.4740843012685, Band=0.19944444444444445
# 22-10-28 13:54:04.764 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:04.765 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_0/PyFstat.cff found.
# 22-10-28 13:54:04.765 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_0/PyFstat.cff
# 22-10-28 13:54:04.765 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:04.765 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_0/H-360_H1_1800SFT_PyFstat-1238166018-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:04.765 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_0" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.1622776601683795e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238166018 --duration=648000 --fmin=497.4740843012685 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_0/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:04.794 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_4/H-360_H1_1800SFT_PyFstat-1238250653-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_4/L-360_L1_1800SFT_PyFstat-1238250653-648000.sft
# 22-10-28 13:54:04.794 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:04.840 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:04.907 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:05.005 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:05.005 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:05.006 pyfstat.make_sfts INFO    : Generating SFTs with fmin=157.5763717216959, Band=0.19944444444444445
# 22-10-28 13:54:05.007 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:05.007 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_4/PyFstat.cff found.
# 22-10-28 13:54:05.007 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_4/PyFstat.cff
# 22-10-28 13:54:05.008 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:05.008 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_4/H-360_H1_1800SFT_PyFstat-1238250653-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:05.009 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_4" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.2211876998506396e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238250653 --duration=648000 --fmin=157.5763717216959 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_4/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:05.121 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_1/H-360_H1_1800SFT_PyFstat-1238187176-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_1/L-360_L1_1800SFT_PyFstat-1238187176-648000.sft
# 22-10-28 13:54:05.121 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:05.167 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:05.185 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:05.238 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:05.238 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:05.239 pyfstat.make_sfts INFO    : Generating SFTs with fmin=369.7777467097873, Band=0.19944444444444445
# 22-10-28 13:54:05.239 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:05.239 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_1/PyFstat.cff found.
# 22-10-28 13:54:05.240 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_1/PyFstat.cff
# 22-10-28 13:54:05.240 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:05.240 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_1/H-360_H1_1800SFT_PyFstat-1238187176-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:05.240 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_1" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.1769033895140374e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238187176 --duration=648000 --fmin=369.7777467097873 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_1/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:06.226 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_5/H-360_H1_1800SFT_PyFstat-1238271812-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_5/L-360_L1_1800SFT_PyFstat-1238271812-648000.sft
# 22-10-28 13:54:06.226 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:06.258 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:06.276 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:06.327 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:06.327 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:06.328 pyfstat.make_sfts INFO    : Generating SFTs with fmin=448.8160579915975, Band=0.19944444444444445
# 22-10-28 13:54:06.329 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:06.329 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_5/PyFstat.cff found.
# 22-10-28 13:54:06.329 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_5/PyFstat.cff
# 22-10-28 13:54:06.330 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:06.330 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_5/H-360_H1_1800SFT_PyFstat-1238271812-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:06.331 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_5" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.2360858917655993e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238271812 --duration=648000 --fmin=448.8160579915975 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_5/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:06.464 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_3/H-360_H1_1800SFT_PyFstat-1238229494-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_3/L-360_L1_1800SFT_PyFstat-1238229494-648000.sft
# 22-10-28 13:54:06.464 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:06.493 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:06.512 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:06.560 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:06.561 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:06.562 pyfstat.make_sfts INFO    : Generating SFTs with fmin=413.0665992052915, Band=0.19944444444444445
# 22-10-28 13:54:06.562 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:06.563 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_3/PyFstat.cff found.
# 22-10-28 13:54:06.563 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_3/PyFstat.cff
# 22-10-28 13:54:06.563 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:06.564 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_3/H-360_H1_1800SFT_PyFstat-1238229494-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:06.564 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_3" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.2063580957698235e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238229494 --duration=648000 --fmin=413.0665992052915 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_3/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:06.636 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_2/H-360_H1_1800SFT_PyFstat-1238208335-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_2/L-360_L1_1800SFT_PyFstat-1238208335-648000.sft
# 22-10-28 13:54:06.637 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:06.666 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:06.685 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:06.734 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:06.734 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:06.735 pyfstat.make_sfts INFO    : Generating SFTs with fmin=89.32227686358067, Band=0.19944444444444445
# 22-10-28 13:54:06.735 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:06.735 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_2/PyFstat.cff found.
# 22-10-28 13:54:06.735 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_2/PyFstat.cff
# 22-10-28 13:54:06.736 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:06.736 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_2/H-360_H1_1800SFT_PyFstat-1238208335-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:06.736 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_2" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.1915967637605545e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238208335 --duration=648000 --fmin=89.32227686358067 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_2/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:07.079 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_0/H-360_H1_1800SFT_PyFstat-1238166018-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_0/L-360_L1_1800SFT_PyFstat-1238166018-648000.sft
# 22-10-28 13:54:07.079 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:07.110 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:07.129 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 13:54:07.181 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 13:54:07.181 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 13:54:07.181 pyfstat.make_sfts INFO    : Generating SFTs with fmin=192.38612438199155, Band=0.19944444444444445
# 22-10-28 13:54:07.182 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 13:54:07.182 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_0/PyFstat.cff found.
# 22-10-28 13:54:07.182 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_0/PyFstat.cff
# 22-10-28 13:54:07.182 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 13:54:07.182 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_0/H-360_H1_1800SFT_PyFstat-1238166018-648000.sft' found. Will create new SFT file(s).
# 22-10-28 13:54:07.182 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_0" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.1622776601683795e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238166018 --duration=648000 --fmin=192.3861243819916 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_3_0/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 13:54:07.280 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_4/H-360_H1_1800SFT_PyFstat-1238250653-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_4/L-360_L1_1800SFT_PyFstat-1238250653-648000.sft
# 22-10-28 13:54:07.280 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 13:54:07.310 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 13:54:07.330 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# ...
# 22-10-28 14:03:53.005 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_30/H-360_H1_1800SFT_PyFstat-1238800782-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_30/L-360_L1_1800SFT_PyFstat-1238800782-648000.sft
# 22-10-28 14:03:53.006 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 14:03:53.038 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 14:03:53.056 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 14:03:53.104 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 14:03:53.105 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 14:03:53.105 pyfstat.make_sfts INFO    : Generating SFTs with fmin=325.9600987198009, Band=0.19944444444444445
# 22-10-28 14:03:53.106 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 14:03:53.106 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_30/PyFstat.cff found.
# 22-10-28 14:03:53.106 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_30/PyFstat.cff
# 22-10-28 14:03:53.106 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 14:03:53.106 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_30/H-360_H1_1800SFT_PyFstat-1238800782-648000.sft' found. Will create new SFT file(s).
# 22-10-28 14:03:53.107 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_30" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.631785919074353e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238800782 --duration=648000 --fmin=325.9600987198009 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_30/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 14:03:53.454 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_47_26/H-360_H1_1800SFT_PyFstat-1238716146-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_47_26/L-360_L1_1800SFT_PyFstat-1238716146-648000.sft
# 22-10-28 14:03:53.454 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 14:03:53.494 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 14:03:53.515 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 14:03:53.572 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 14:03:53.573 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 14:03:53.573 pyfstat.make_sfts INFO    : Generating SFTs with fmin=376.38730507209993, Band=0.19944444444444445
# 22-10-28 14:03:53.574 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 14:03:53.574 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_26/PyFstat.cff found.
# 22-10-28 14:03:53.575 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_26/PyFstat.cff
# 22-10-28 14:03:53.575 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 14:03:53.576 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_26/H-360_H1_1800SFT_PyFstat-1238716146-648000.sft' found. Will create new SFT file(s).
# 22-10-28 14:03:53.576 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_26" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.5653667369136376e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238716146 --duration=648000 --fmin=376.3873050720999 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_26/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 14:03:53.757 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_27/H-360_H1_1800SFT_PyFstat-1238737305-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_27/L-360_L1_1800SFT_PyFstat-1238737305-648000.sft
# 22-10-28 14:03:53.757 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 14:03:53.786 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 14:03:53.802 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 14:03:53.850 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 14:03:53.850 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 14:03:53.851 pyfstat.make_sfts INFO    : Generating SFTs with fmin=408.72887818296647, Band=0.19944444444444445
# 22-10-28 14:03:53.851 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 14:03:53.852 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_49_27/PyFstat.cff found.
# 22-10-28 14:03:53.852 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_49_27/PyFstat.cff
# 22-10-28 14:03:53.853 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 14:03:53.853 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_49_27/H-360_H1_1800SFT_PyFstat-1238737305-648000.sft' found. Will create new SFT file(s).
# 22-10-28 14:03:53.853 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_49_27" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.58185677811683e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238737305 --duration=648000 --fmin=408.7288781829665 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_49_27/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 14:03:53.891 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_47_28/H-360_H1_1800SFT_PyFstat-1238758464-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_47_28/L-360_L1_1800SFT_PyFstat-1238758464-648000.sft
# 22-10-28 14:03:53.892 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 14:03:53.931 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 14:03:53.950 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 14:03:54.006 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 14:03:54.007 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 14:03:54.007 pyfstat.make_sfts INFO    : Generating SFTs with fmin=487.4937579682635, Band=0.19944444444444445
# 22-10-28 14:03:54.008 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 14:03:54.008 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_28/PyFstat.cff found.
# 22-10-28 14:03:54.008 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_28/PyFstat.cff
# 22-10-28 14:03:54.008 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 14:03:54.008 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_28/H-360_H1_1800SFT_PyFstat-1238758464-648000.sft' found. Will create new SFT file(s).
# 22-10-28 14:03:54.009 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_28" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.598423086778308e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238758464 --duration=648000 --fmin=487.4937579682635 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_28/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 14:03:54.054 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_49_25/H-360_H1_1800SFT_PyFstat-1238694988-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_49_25/L-360_L1_1800SFT_PyFstat-1238694988-648000.sft
# 22-10-28 14:03:54.054 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 14:03:54.084 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 14:03:54.102 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 14:03:54.152 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 14:03:54.152 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 14:03:54.153 pyfstat.make_sfts INFO    : Generating SFTs with fmin=441.23747187033536, Band=0.19944444444444445
# 22-10-28 14:03:54.153 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 14:03:54.153 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_31/PyFstat.cff found.
# 22-10-28 14:03:54.154 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_31/PyFstat.cff
# 22-10-28 14:03:54.154 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 14:03:54.154 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_31/H-360_H1_1800SFT_PyFstat-1238821940-648000.sft' found. Will create new SFT file(s).
# 22-10-28 14:03:54.154 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_31" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.6485831530942245e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238821940 --duration=648000 --fmin=441.2374718703354 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_0_31/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 14:03:54.988 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_47_29/H-360_H1_1800SFT_PyFstat-1238779623-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_47_29/L-360_L1_1800SFT_PyFstat-1238779623-648000.sft
# 22-10-28 14:03:54.988 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 14:03:55.023 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 14:03:55.041 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 14:03:55.090 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 14:03:55.090 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 14:03:55.091 pyfstat.make_sfts INFO    : Generating SFTs with fmin=189.874642722116, Band=0.19944444444444445
# 22-10-28 14:03:55.091 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 14:03:55.091 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_29/PyFstat.cff found.
# 22-10-28 14:03:55.092 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_29/PyFstat.cff
# 22-10-28 14:03:55.092 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 14:03:55.092 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_29/H-360_H1_1800SFT_PyFstat-1238779623-648000.sft' found. Will create new SFT file(s).
# 22-10-28 14:03:55.092 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_29" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.615066015639746e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238779623 --duration=648000 --fmin=189.874642722116 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_48_29/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"
# 22-10-28 14:03:55.384 pyfstat.make_sfts INFO    : Successfully wrote SFTs to: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_30/H-360_H1_1800SFT_PyFstat-1238800782-648000.sft;/5-generate-signals/TMP_NOT-SO-PURE_signals_true_1_30/L-360_L1_1800SFT_PyFstat-1238800782-648000.sft
# 22-10-28 14:03:55.384 pyfstat.make_sfts INFO    : Now validating each SFT file...
# 22-10-28 14:03:55.418 pyfstat.utils.sft INFO    : Loading 360 SFTs from H1...
# 22-10-28 14:03:55.438 pyfstat.utils.sft INFO    : Loading 360 SFTs from L1...
# 22-10-28 14:03:55.486 pyfstat.core INFO    : Creating Writer object...
# 22-10-28 14:03:55.487 pyfstat.utils.ephemeris INFO    : No /home/jupyter/.pyfstat.conf file found. Will fall back to lal's automatic path resolution for files [earth00-40-DE405.dat.gz,sun00-40-DE405.dat.gz]. Alternatively, set 'earth_ephem' and 'sun_ephem' class options.
# 22-10-28 14:03:55.487 pyfstat.make_sfts INFO    : Generating SFTs with fmin=481.43978907238795, Band=0.19944444444444445
# 22-10-28 14:03:55.488 pyfstat.make_sfts INFO    : Checking if we can re-use injection config file...
# 22-10-28 14:03:55.488 pyfstat.make_sfts INFO    : ...no config file /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_30/PyFstat.cff found.
# 22-10-28 14:03:55.488 pyfstat.make_sfts INFO    : Writing config file: /5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_30/PyFstat.cff
# 22-10-28 14:03:55.488 pyfstat.make_sfts INFO    : Checking if we can re-use existing SFT data file(s)...
# 22-10-28 14:03:55.488 pyfstat.make_sfts INFO    : ...no SFT file matching '/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_30/H-360_H1_1800SFT_PyFstat-1238800782-648000.sft' found. Will create new SFT file(s).
# 22-10-28 14:03:55.489 pyfstat.utils.cli INFO    : Now executing: lalapps_Makefakedata_v5 --outSingleSFT=TRUE --outSFTdir="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_30" --outLabel="PyFstat" --IFOs="H1","L1" --sqrtSX="3.631785919074353e-24" --SFTWindowType="tukey" --SFTWindowBeta=0.01 --startTime=1238800782 --duration=648000 --fmin=481.439789072388 --Band=0.1994444444444445 --Tsft=1800 --injectionSources="/5-generate-signals/TMP_NOT-SO-PURE_signals_true_2_30/PyFstat.cff" --ephemEarth="earth00-40-DE405.dat.gz" --ephemSun="sun00-40-DE405.dat.gz"

# %% [markdown]
# # TEST

# %%
paths =  ['./tmp/Signal_0_0/H-100_H1_1800SFT_Signal_0-1238166018-180000.sft', './tmp/Signal_0_0/L-100_L1_1800SFT_Signal_0-1238166018-180000.sft'] 
path = paths[0]
frequency, timestamps, amplitudes_0 = pyfstat.utils.get_sft_as_arrays(path)
path = paths[1]
frequency, timestamps, amplitudes_1 = pyfstat.utils.get_sft_as_arrays(path)
x = combine_amplitudes(amplitudes_0["H1"], amplitudes_1["L1"])
x.shape
