# %%
PREPROC_TRAIN_DATA = False

# %%
import tensorflow as tf
from gradient_accumulator.GAModelWrapper import GAModelWrapper


######### MODEL #########


base_model = tf.keras.applications.ResNet152V2(include_top=True, 
                                                   weights=None, 
                                                input_shape=(360, 256, 2), 
                                                classes=1,
                                                classifier_activation="sigmoid")
inputs = tf.keras.Input(shape=(360, 256, 2))
x = base_model(inputs, training=True)
model = tf.keras.Model(inputs, x)

model = GAModelWrapper(accum_steps=1, inputs=model.input, outputs=model.output)


model.load_weights("model.h5")
# Out:
# /home/viktor/.local/lib/python3.10/site-packages/keras/applications/resnet.py:135: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 2 input channels.
#   input_shape = imagenet_utils.obtain_input_shape(
# 2022-12-23 17:38:48.504560: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-23 17:38:48.526985: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-23 17:38:48.527181: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-23 17:38:48.527609: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-23 17:38:48.528321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-23 17:38:48.528474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-23 17:38:48.528603: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-23 17:38:48.878212: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-23 17:38:48.878384: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-23 17:38:48.878513: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-23 17:38:48.878638: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2308 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
import pandas as pd
if PREPROC_TRAIN_DATA:
    df = pd.read_csv("/media/viktor/T7/gravitational-waves-kaggle-2022/kaggle-data/preprocessed/train-preprocessed.csv")
else:
    df = pd.read_csv("/media/viktor/T7/gravitational-waves-kaggle-2022/kaggle-data/preprocessed/test-preprocessed.csv")
df
# Out:
#       Unnamed: 0                                           filename  \
# 0              0  /media/viktor/T7/gravitational-waves-kaggle-20...
# 1              1  /media/viktor/T7/gravitational-waves-kaggle-20...
# 2              2  /media/viktor/T7/gravitational-waves-kaggle-20...
# 3              3  /media/viktor/T7/gravitational-waves-kaggle-20...
# 4              4  /media/viktor/T7/gravitational-waves-kaggle-20...
# ...          ...                                                ...
# 7970        7970  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7971        7971  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7972        7972  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7973        7973  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7974        7974  /media/viktor/T7/gravitational-waves-kaggle-20...
#
#            name                              preprocessed_filename
# 0     00054c878  /media/viktor/T7/gravitational-waves-kaggle-20...
# 1     0007285a3  /media/viktor/T7/gravitational-waves-kaggle-20...
# 2     00076c5a6  /media/viktor/T7/gravitational-waves-kaggle-20...
# 3     001349290  /media/viktor/T7/gravitational-waves-kaggle-20...
# 4     001a52e92  /media/viktor/T7/gravitational-waves-kaggle-20...
# ...         ...                                                ...
# 7970  ffbce04ef  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7971  ffc2d976b  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7972  ffc905909  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7973  ffe276f3e  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7974  fffa17f67  /media/viktor/T7/gravitational-waves-kaggle-20...
#
# [7975 rows x 4 columns]

# %%
# Replace "/media/viktor/T7/gravitational-waves-kaggle-2022/train" with "/media/viktor/T7/gravitational-waves-kaggle-2022/kaggle-data/preprocessed/train" in preprocessed_filename
df["preprocessed_filename"] = df["preprocessed_filename"].apply(lambda x: x.replace("/media/viktor/T7/gravitational-waves-kaggle-2022", "/media/viktor/T7/gravitational-waves-kaggle-2022/kaggle-data/preprocessed"))

# %%
# Loop over the dataset and make predictions: save the predictions to a list and create a column in the dataframe
# with the predictions
import numpy as np
from tqdm import tqdm
predictions = []
for i in tqdm(range(len(df))):
    # Get the path to the file
    path = df.iloc[i]["preprocessed_filename"]
    # Load the data
    data = np.load(path)
    # Reshape the data
    data = data.reshape(1, 360, 256, 2)
    # Make a prediction
    prediction = model.predict(data, verbose=0)
    # Save the prediction
    predictions.append(prediction[0][0])
    
    if i % 1000 == 0:
        # clear backed memory
        tf.keras.backend.clear_session()
    
df["prediction"] = predictions
df
# Out:
# 100%|██████████| 7975/7975 [10:01<00:00, 13.25it/s]
#       Unnamed: 0                                           filename  \
# 0              0  /media/viktor/T7/gravitational-waves-kaggle-20...
# 1              1  /media/viktor/T7/gravitational-waves-kaggle-20...
# 2              2  /media/viktor/T7/gravitational-waves-kaggle-20...
# 3              3  /media/viktor/T7/gravitational-waves-kaggle-20...
# 4              4  /media/viktor/T7/gravitational-waves-kaggle-20...
# ...          ...                                                ...
# 7970        7970  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7971        7971  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7972        7972  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7973        7973  /media/viktor/T7/gravitational-waves-kaggle-20...
# 7974        7974  /media/viktor/T7/gravitational-waves-kaggle-20...
#
#            name                              preprocessed_filename  prediction
# 0     00054c878  /media/viktor/T7/gravitational-waves-kaggle-20...    0.581619
# 1     0007285a3  /media/viktor/T7/gravitational-waves-kaggle-20...    0.681830
# 2     00076c5a6  /media/viktor/T7/gravitational-waves-kaggle-20...    0.579205
# 3     001349290  /media/viktor/T7/gravitational-waves-kaggle-20...    0.566956
# 4     001a52e92  /media/viktor/T7/gravitational-waves-kaggle-20...    0.578165
# ...         ...                                                ...         ...
# 7970  ffbce04ef  /media/viktor/T7/gravitational-waves-kaggle-20...    0.606945
# 7971  ffc2d976b  /media/viktor/T7/gravitational-waves-kaggle-20...    0.599037
# 7972  ffc905909  /media/viktor/T7/gravitational-waves-kaggle-20...    0.595632
# 7973  ffe276f3e  /media/viktor/T7/gravitational-waves-kaggle-20...    0.573934
# 7974  fffa17f67  /media/viktor/T7/gravitational-waves-kaggle-20...    0.577319
#
# [7975 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.hist(df["prediction"], bins=100);

# %%
# calculate auc
from sklearn.metrics import roc_auc_score
if PREPROC_TRAIN_DATA:
    print(roc_auc_score(df["target"], df["prediction"]))

# %%
df_sub = df[["name", "prediction"]]
# rename prediction to target
df_sub = df_sub.rename(columns={"prediction": "target",
                                "name": "id"})
df_sub.to_csv("submission.csv", index=False)
df_sub
# Out:
#              id    target
# 0     00054c878  0.581619
# 1     0007285a3  0.681830
# 2     00076c5a6  0.579205
# 3     001349290  0.566956
# 4     001a52e92  0.578165
# ...         ...       ...
# 7970  ffbce04ef  0.606945
# 7971  ffc2d976b  0.599037
# 7972  ffc905909  0.595632
# 7973  ffe276f3e  0.573934
# 7974  fffa17f67  0.577319
#
# [7975 rows x 2 columns]

# %%
if PREPROC_TRAIN_DATA:
    df.to_csv("train_predictions.csv", index=False)
else:
    df.to_csv("test_predictions.csv", index=False)

# %%
import numpy as np
from PIL import Image

np.array(Image.open(f"/media/viktor/T7/gravitational-waves-kaggle-2022/datasets/realistic_noise_256/realistic_noise/images/0a1a06b36/L1.png")).min()
# Out:
# 29
