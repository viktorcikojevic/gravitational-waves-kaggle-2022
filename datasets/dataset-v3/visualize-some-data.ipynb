# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("data.csv")
df
# Out:
#                                                     file  label      depth
# 0      /media/viktor/T7/gravitational-waves-kaggle-20...      0  20.215531
# 1      /media/viktor/T7/gravitational-waves-kaggle-20...      0  10.718041
# 2      /media/viktor/T7/gravitational-waves-kaggle-20...      1  24.091261
# 3      /media/viktor/T7/gravitational-waves-kaggle-20...      1  13.206084
# 4      /media/viktor/T7/gravitational-waves-kaggle-20...      1  19.693785
# ...                                                  ...    ...        ...
# 79995  /media/viktor/T7/gravitational-waves-kaggle-20...      1  16.749783
# 79996  /media/viktor/T7/gravitational-waves-kaggle-20...      1  24.758797
# 79997  /media/viktor/T7/gravitational-waves-kaggle-20...      0  11.961803
# 79998  /media/viktor/T7/gravitational-waves-kaggle-20...      1  19.257319
# 79999  /media/viktor/T7/gravitational-waves-kaggle-20...      0  21.888044
#
# [80000 rows x 3 columns]

# %%
df_1 = df[df["label"] == 1].reset_index(drop=True)

indx = np.random.randint(0, len(df_1))
file = df_1["file"].iloc[indx]
depth = df_1["depth"].iloc[indx]
print(f"Depth: {depth}")
x = np.load(file)

# figure 1:
plt.figure(figsize=(20, 10))
plt.imshow(x[:,:,1], aspect="auto", origin="lower")
# Out:
# Depth: 20.329917400592453
